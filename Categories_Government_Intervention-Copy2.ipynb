# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#from government intervetions google drive file, errors showing 2019 in index 33 changed to 2020
#filter values were changed so Namibia could be read
df_cat_gov_int = pd.read_csv('government interventions - measures-small.csv', keep_default_na=False, na_values=[''])

# %%
#lots of empty data 
df_cat_gov_int.head()
# Out:
#          actions/0/name adm/0  adm/1  adm/2                  date  \
# 0        schools_closed    AF    NaN    NaN  2020-03-17T00:00:00Z
# 1                   NaN    AL    NaN    NaN  2020-03-10T00:00:00Z
# 2  traveller_quarantine    AL    NaN    NaN  2020-02-25T00:00:00Z
# 3        border_control    AL    NaN    NaN  2020-03-08T00:00:00Z
# 4        border_control    AL    NaN    NaN  2020-03-12T00:00:00Z
#
#   schools_closed                                             source  \
# 0           True  https://www.aljazeera.com/news/2020/03/war-rav...
# 1            NaN  https://www.albaniandailynews.com/index.php?id...
# 2            NaN  https://balkaneu.com/albania-national-medical-...
# 3           True  https://uk.reuters.com/article/uk-health-coron...
# 4           True  https://balkaninsight.com/2020/03/12/albania-c...
#
#              sourceFull/_id  \
# 0  5e764db948154944524ea035
# 1  5e76719f0b86158bd45e9852
# 2  5e7671a00b86158bd45e9857
# 3  5e7671a10b86158bd45e985d
# 4  5e7671a20b86158bd45e9865
#
#                                       sourceFull/url traveller_quarantine  \
# 0  https://www.aljazeera.com/news/2020/03/war-rav...                  NaN
# 1  https://www.albaniandailynews.com/index.php?id...                  NaN
# 2  https://balkaneu.com/albania-national-medical-...                 True
# 3  https://uk.reuters.com/article/uk-health-coron...                 True
# 4  https://balkaninsight.com/2020/03/12/albania-c...                 True
#
#    ...        actions/4/name closure_leisureandbars lockdown home_office  \
# 0  ...                   NaN                    NaN      NaN         NaN
# 1  ...                   NaN                    NaN      NaN         NaN
# 2  ...                   NaN                    NaN      NaN         NaN
# 3  ...                   NaN                    NaN      NaN         NaN
# 4  ...  traveller_quarantine                   True     True         NaN
#
#   primary_residence test_limitations actions/5/_id actions/5/name  \
# 0               NaN              NaN           NaN            NaN
# 1               NaN              NaN           NaN            NaN
# 2               NaN              NaN           NaN            NaN
# 3               NaN              NaN           NaN            NaN
# 4               NaN              NaN           NaN            NaN
#
#   actions/6/_id actions/6/name
# 0           NaN            NaN
# 1           NaN            NaN
# 2           NaN            NaN
# 3           NaN            NaN
# 4           NaN            NaN
#
# [5 rows x 28 columns]

# %%
df_cat_gov_int.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2293 entries, 0 to 2292
# Data columns (total 28 columns):
# actions/0/name            2258 non-null object
# adm/0                     2143 non-null object
# adm/1                     124 non-null float64
# adm/2                     44 non-null float64
# date                      2293 non-null object
# schools_closed            2151 non-null object
# source                    2274 non-null object
# sourceFull/_id            2293 non-null object
# sourceFull/url            2274 non-null object
# traveller_quarantine      102 non-null object
# actions/1/_id             201 non-null object
# actions/1/name            201 non-null object
# actions/2/_id             124 non-null object
# actions/2/name            124 non-null object
# border_control            142 non-null object
# actions/3/_id             57 non-null object
# actions/3/name            57 non-null object
# actions/4/_id             32 non-null object
# actions/4/name            32 non-null object
# closure_leisureandbars    145 non-null object
# lockdown                  75 non-null object
# home_office               37 non-null object
# primary_residence         27 non-null object
# test_limitations          21 non-null object
# actions/5/_id             18 non-null object
# actions/5/name            18 non-null object
# actions/6/_id             10 non-null object
# actions/6/name            10 non-null object
# dtypes: float64(2), object(26)
# memory usage: 501.7+ KB

# %%
df_cat_gov_int[df_cat_gov_int['adm/0']=='NA']
# Out:
#       actions/0/name adm/0  adm/1  adm/2                  date schools_closed  \
# 953   schools_closed    NA    NaN    NaN  2020-03-16T00:00:00Z           True
# 954   schools_closed    NA    NaN    NaN  2020-03-19T00:00:00Z           True
# 955   schools_closed    NA    NaN    NaN  2020-03-17T00:00:00Z           True
# 956   schools_closed    NA    NaN    NaN  2020-03-18T00:00:00Z           True
# 957   schools_closed    NA    NaN    NaN  2020-03-20T00:00:00Z           True
# 1912  schools_closed    NA    NaN    NaN  2020-03-16T00:00:00Z           True
# 1913  schools_closed    NA    NaN    NaN  2020-03-19T00:00:00Z           True
# 1914  schools_closed    NA    NaN    NaN  2020-03-17T00:00:00Z           True
# 1915  schools_closed    NA    NaN    NaN  2020-03-18T00:00:00Z           True
# 1916  schools_closed    NA    NaN    NaN  2020-03-20T00:00:00Z           True
#
#                       source            sourceFull/_id  \
# 953   http://www.unesco.com/  5e7668b3e04e7c3ebeceadb0
# 954   http://www.unesco.com/  5e7668b3e04e7c3ebeceadb0
# 955   http://www.unesco.com/  5e7668b3e04e7c3ebeceadb0
# 956   http://www.unesco.com/  5e7668b3e04e7c3ebeceadb0
# 957   http://www.unesco.com/  5e7668b3e04e7c3ebeceadb0
# 1912  http://www.unesco.com/  5e7668b3e04e7c3ebeceadb0
# 1913  http://www.unesco.com/  5e7668b3e04e7c3ebeceadb0
# 1914  http://www.unesco.com/  5e7668b3e04e7c3ebeceadb0
# 1915  http://www.unesco.com/  5e7668b3e04e7c3ebeceadb0
# 1916  http://www.unesco.com/  5e7668b3e04e7c3ebeceadb0
#
#               sourceFull/url traveller_quarantine  ... actions/4/name  \
# 953   http://www.unesco.com/                  NaN  ...            NaN
# 954   http://www.unesco.com/                  NaN  ...            NaN
# 955   http://www.unesco.com/                  NaN  ...            NaN
# 956   http://www.unesco.com/                  NaN  ...            NaN
# 957   http://www.unesco.com/                  NaN  ...            NaN
# 1912  http://www.unesco.com/                  NaN  ...            NaN
# 1913  http://www.unesco.com/                  NaN  ...            NaN
# 1914  http://www.unesco.com/                  NaN  ...            NaN
# 1915  http://www.unesco.com/                  NaN  ...            NaN
# 1916  http://www.unesco.com/                  NaN  ...            NaN
#
#      closure_leisureandbars lockdown home_office primary_residence  \
# 953                     NaN      NaN         NaN               NaN
# 954                     NaN      NaN         NaN               NaN
# 955                     NaN      NaN         NaN               NaN
# 956                     NaN      NaN         NaN               NaN
# 957                     NaN      NaN         NaN               NaN
# 1912                    NaN      NaN         NaN               NaN
# 1913                    NaN      NaN         NaN               NaN
# 1914                    NaN      NaN         NaN               NaN
# 1915                    NaN      NaN         NaN               NaN
# 1916                    NaN      NaN         NaN               NaN
#
#      test_limitations actions/5/_id actions/5/name actions/6/_id  \
# 953               NaN           NaN            NaN           NaN
# 954               NaN           NaN            NaN           NaN
# 955               NaN           NaN            NaN           NaN
# 956               NaN           NaN            NaN           NaN
# 957               NaN           NaN            NaN           NaN
# 1912              NaN           NaN            NaN           NaN
# 1913              NaN           NaN            NaN           NaN
# 1914              NaN           NaN            NaN           NaN
# 1915              NaN           NaN            NaN           NaN
# 1916              NaN           NaN            NaN           NaN
#
#      actions/6/name
# 953             NaN
# 954             NaN
# 955             NaN
# 956             NaN
# 957             NaN
# 1912            NaN
# 1913            NaN
# 1914            NaN
# 1915            NaN
# 1916            NaN
#
# [10 rows x 28 columns]

# %%
#to make the dates datetime datatypes
df_cat_gov_int.date = df_cat_gov_int.date.apply(lambda x: pd.Timestamp(x, unit='D'))

# %%
df_cat_gov_int.date
# Out:
# 0      2020-03-17 00:00:00+00:00
# 1      2020-03-10 00:00:00+00:00
# 2      2020-02-25 00:00:00+00:00
# 3      2020-03-08 00:00:00+00:00
# 4      2020-03-12 00:00:00+00:00
#                   ...
# 2288   2020-03-12 00:00:00+00:00
# 2289   2020-03-14 00:00:00+00:00
# 2290   2020-03-12 00:00:00+00:00
# 2291   2020-03-18 00:00:00+00:00
# 2292   2020-03-16 00:00:00+00:00
# Name: date, Length: 2293, dtype: datetime64[ns, UTC]

# %%
#primary actions taken, the actions are also column names with true or false values
df_cat_gov_int['actions/0/name'].value_counts()
# Out:
# schools_closed            1990
# border_control             142
# closure_leisureandbars      80
# lockdown                    18
# traveller_quarantine        12
# home_office                  7
# primary_residence            5
# test_limitations             4
# Name: actions/0/name, dtype: int64

# %%
#these countries seem to have the most info on them, or actions taken in different parts at different times
df_cat_gov_int['adm/0'].value_counts().head(10)
# Out:
# CN    158
# MN     62
# US     59
# IT     54
# IR     49
# BH     48
# KR     40
# JP     39
# AM     39
# KP     38
# Name: adm/0, dtype: int64

# %%
#If there is no primary action, they don't take further actions, so any without primary actions can be dropped
(df_cat_gov_int.loc[df_cat_gov_int['actions/0/name'].isnull()]['actions/1/name'].notnull().sum()+
 df_cat_gov_int.loc[df_cat_gov_int['actions/0/name'].isnull()]['actions/2/name'].notnull().sum()+
 df_cat_gov_int.loc[df_cat_gov_int['actions/0/name'].isnull()]['actions/3/name'].notnull().sum()+
 df_cat_gov_int.loc[df_cat_gov_int['actions/0/name'].isnull()]['actions/4/name'].notnull().sum())
# Out:
# 0

# %%
# csv made from values taken from https://www.worldatlas.com/aatlas/ctycodes.html, EU was manually added
# NA is Namibia, so the filter is set to false 
df_country_codes = pd.read_csv('Country_Codes.csv',na_filter = False)

# %%
df_country_codes.count()
# Out:
# COUNTRY         249
# A2 (ISO)        249
# A3 (UN)         249
# NUM (UN)        249
# DIALING CODE    249
# dtype: int64

# %%
#country with the most info is china
df_country_codes[df_country_codes['A2 (ISO)']=='CN']
# Out:
#    COUNTRY A2 (ISO) A3 (UN)  NUM (UN) DIALING CODE
# 44   China       CN     CHN       156           86

# %%
#I guess some rows just make some data sources known
#df_cat_gov_int.iloc[1]

# %%
#drop rows where there the country isn't known or actions aren't taken 
df_cgi_drop = df_cat_gov_int.dropna(subset=['actions/0/name','adm/0'])

# %%
df_cgi_drop['adm/0'].describe()
# Out:
# count     2124
# unique     135
# top         CN
# freq       152
# Name: adm/0, dtype: object

# %%
#Keeping only columns that may be used, index is reset, but original index has the column name 'old_index'
df_clean = df_cgi_drop[['adm/0',
 'date',
 'schools_closed',
 'traveller_quarantine',
 'border_control',
 'closure_leisureandbars',
 'lockdown',
 'home_office',
 'primary_residence',
 'test_limitations']].reset_index().rename(columns={'index':'old_index'})

# %%
df_clean.head()
# Out:
#    old_index adm/0                      date schools_closed  \
# 0          0    AF 2020-03-17 00:00:00+00:00           True
# 1          2    AL 2020-02-25 00:00:00+00:00            NaN
# 2          3    AL 2020-03-08 00:00:00+00:00           True
# 3          4    AL 2020-03-12 00:00:00+00:00           True
# 4          5    DZ 2020-03-19 00:00:00+00:00            NaN
#
#   traveller_quarantine border_control closure_leisureandbars lockdown  \
# 0                  NaN            NaN                    NaN      NaN
# 1                 True            NaN                    NaN      NaN
# 2                 True           True                    NaN      NaN
# 3                 True           True                   True     True
# 4                  NaN           True                    NaN      NaN
#
#   home_office primary_residence test_limitations
# 0         NaN               NaN              NaN
# 1         NaN               NaN              NaN
# 2         NaN               NaN              NaN
# 3         NaN               NaN              NaN
# 4         NaN               NaN              NaN

# %%
#China started test limitations on 21 of Jan and all other actions two days later, 
#later actions were probably expansions to more parts of the country, 
#actions only show up as true in the row that happen (not if they only already occurred before)
df_clean[df_clean['adm/0']=='CN'].sort_values(by='date').head()
# Out:
#       old_index adm/0                      date schools_closed  \
# 33           38    CN 2020-01-21 00:00:00+00:00            NaN
# 34           40    CN 2020-01-23 00:00:00+00:00           True
# 395         415    CN 2020-02-21 00:00:00+00:00           True
# 1354       1374    CN 2020-02-21 00:00:00+00:00           True
# 1331       1351    CN 2020-02-22 00:00:00+00:00           True
#
#      traveller_quarantine border_control closure_leisureandbars lockdown  \
# 33                    NaN            NaN                    NaN      NaN
# 34                   True           True                   True     True
# 395                   NaN            NaN                    NaN      NaN
# 1354                  NaN            NaN                    NaN      NaN
# 1331                  NaN            NaN                    NaN      NaN
#
#      home_office primary_residence test_limitations
# 33           NaN               NaN             True
# 34          True              True              NaN
# 395          NaN               NaN              NaN
# 1354         NaN               NaN              NaN
# 1331         NaN               NaN              NaN

# %%
#actions were taken from 21 of January to 24 of March
df_clean.date.sort_values()
# Out:
# 33    2020-01-21 00:00:00+00:00
# 132   2020-01-23 00:00:00+00:00
# 34    2020-01-23 00:00:00+00:00
# 133   2020-01-23 00:00:00+00:00
# 99    2020-01-25 00:00:00+00:00
#                  ...
# 139   2020-03-22 00:00:00+00:00
# 152   2020-03-23 00:00:00+00:00
# 6     2020-03-23 00:00:00+00:00
# 103   2020-03-23 00:00:00+00:00
# 38    2020-03-24 00:00:00+00:00
# Name: date, Length: 2124, dtype: datetime64[ns, UTC]

# %%
#a method to find first time occurrences' index number
(df_clean[df_clean['adm/0']=='CN'].sort_values(by='date')['schools_closed'].cumsum() == 1).idxmax()
# Out:
# 34

# %%
#all actions
actions = ['schools_closed',
 'traveller_quarantine',
 'border_control',
 'closure_leisureandbars',
 'lockdown',
 'home_office',
 'primary_residence',
 'test_limitations']

# %%
#country codes used in the loops below
country_codes = df_clean['adm/0'].tolist()

# %%
start_dates_FI = []
used_actions = []
for i in actions:    
    check = (df_clean[df_clean['adm/0']=='FI'].sort_values(by='date')[i].cumsum() == 1).values[0]
    if check == False:
        continue
    else:
        start_date_FI = df_clean.iloc[(df_clean[df_clean['adm/0']=='FI'].sort_values(by='date')[i].cumsum() == 1).idxmax()].date 
        start_dates_FI.append(start_date_FI)
        if True in df_clean[df_clean['adm/0']=='FI'][i].values:
            used_actions.append(i)
#shows the start dates for actions taken in Finland; they did not do all actions
print(start_dates_FI) 
df_FL = pd.DataFrame({'FI': start_dates_FI}, index=used_actions)
df_FL
# Out:
# [Timestamp('2020-03-18 00:00:00+0000', tz='UTC')]
#                                       FI
# schools_closed 2020-03-18 00:00:00+00:00

# %%
start_dates_sc = []
cl = []
for j in country_codes:
    if j in cl:
        continue
    else:
        check = (df_clean[df_clean['adm/0']==j].sort_values(by='date')['schools_closed'].cumsum() == 1).values[0]
        if check == False:
            continue
        else:
            start_date_sc = df_clean.iloc[(df_clean[df_clean['adm/0']==j].sort_values(by='date')['schools_closed'].cumsum() == 1).idxmax()].date#[0:10]
            start_dates_sc.append(start_date_sc)
    cl.append(j)
#shows the start dates schools closed for each country
#print(start_dates_sc) 
df_sc = pd.DataFrame({'schools_closed':start_dates_sc}, index = cl)
df_sc.head()
# Out:
#               schools_closed
# AF 2020-03-14 00:00:00+00:00
# DZ 2020-03-12 00:00:00+00:00
# AM 2020-03-02 00:00:00+00:00
# BE 2020-03-13 00:00:00+00:00
# BO 2020-03-12 00:00:00+00:00

# %%
start_dates = []
country_list = []
for j in country_codes:
    if j in country_list:
        continue
    else:
        for i in actions:
            #see if action is done
            check = (df_clean[df_clean['adm/0']==j].sort_values(by='date')[i].cumsum() == 1).values.any()
            if check == False:
                start_dates.append(np.datetime64('NaT'))
            else:
                #getting dates actions started
                start_date = df_clean.iloc[(df_clean[df_clean['adm/0']==j].sort_values(by='date')[i].cumsum() == 1).idxmax()].date 
                start_dates.append(start_date)
                if True in df_clean[df_clean['adm/0']==j][i].values:
                    used_actions.append(i)            
               
        country_list.append(j)
#start dates for each country for each action
print(start_dates[0:8])
# Out:
# [Timestamp('2020-03-14 00:00:00+0000', tz='UTC'), numpy.datetime64('NaT'), numpy.datetime64('NaT'), numpy.datetime64('NaT'), numpy.datetime64('NaT'), numpy.datetime64('NaT'), numpy.datetime64('NaT'), numpy.datetime64('NaT')]

# %%
#there is a start date for each action for each country
len(start_dates)/len(country_list) == len(actions)
# Out:
# True

# %%
#this is a dataframe with each country and start date for actions taken 
df = pd.DataFrame([start_dates[i:i+8] for i in range(0,len(start_dates),8)], columns = actions, index = country_list).reset_index().rename(columns={'index':'cc_index'})
df
# Out:
#     cc_index             schools_closed       traveller_quarantine  \
# 0         AF  2020-03-14 00:00:00+00:00                        NaT
# 1         AL  2020-03-08 00:00:00+00:00  2020-02-25 00:00:00+00:00
# 2         DZ  2020-03-12 00:00:00+00:00                        NaT
# 3         AS  2020-03-23 00:00:00+00:00  2020-03-17 00:00:00+00:00
# 4         AR  2020-03-15 00:00:00+00:00  2020-03-12 00:00:00+00:00
# ..       ...                        ...                        ...
# 130       UZ  2020-03-16 00:00:00+00:00                        NaT
# 131       VC  2020-03-16 00:00:00+00:00                        NaT
# 132       VE  2020-03-17 00:00:00+00:00                        NaT
# 133       ZA  2020-03-18 00:00:00+00:00                        NaT
# 134       ZM  2020-03-20 00:00:00+00:00                        NaT
#
#                 border_control     closure_leisureandbars  \
# 0                          NaT                        NaT
# 1    2020-03-08 00:00:00+00:00  2020-03-12 00:00:00+00:00
# 2    2020-03-19 00:00:00+00:00                        NaT
# 3                          NaT  2020-03-23 00:00:00+00:00
# 4    2020-03-15 00:00:00+00:00                        NaT
# ..                         ...                        ...
# 130                        NaT                        NaT
# 131                        NaT                        NaT
# 132                        NaT                        NaT
# 133                        NaT                        NaT
# 134                        NaT                        NaT
#
#                       lockdown                home_office  \
# 0                          NaT                        NaT
# 1    2020-03-12 00:00:00+00:00                        NaT
# 2                          NaT                        NaT
# 3                          NaT                        NaT
# 4    2020-03-16 00:00:00+00:00  2020-03-17 00:00:00+00:00
# ..                         ...                        ...
# 130                        NaT                        NaT
# 131                        NaT                        NaT
# 132                        NaT                        NaT
# 133                        NaT                        NaT
# 134                        NaT                        NaT
#
#              primary_residence test_limitations
# 0                          NaT              NaT
# 1                          NaT              NaT
# 2                          NaT              NaT
# 3                          NaT              NaT
# 4    2020-03-17 00:00:00+00:00              NaT
# ..                         ...              ...
# 130                        NaT              NaT
# 131                        NaT              NaT
# 132                        NaT              NaT
# 133                        NaT              NaT
# 134                        NaT              NaT
#
# [135 rows x 9 columns]

# %%
#Seems to have worked
df[df['cc_index']=='CN']
# Out:
#    cc_index             schools_closed       traveller_quarantine  \
# 15       CN  2020-01-23 00:00:00+00:00  2020-01-23 00:00:00+00:00
#
#                border_control     closure_leisureandbars  \
# 15  2020-01-23 00:00:00+00:00  2020-01-23 00:00:00+00:00
#
#                      lockdown                home_office  \
# 15  2020-01-23 00:00:00+00:00  2020-01-23 00:00:00+00:00
#
#             primary_residence           test_limitations
# 15  2020-01-23 00:00:00+00:00  2020-01-21 00:00:00+00:00

# %%
#histogram of school closure dates (without country labels)
#if one knows how to turn a histogram into labelled data points, That'd be cool
df.schools_closed.sort_values().hist(grid=False, xrot=90)

# %%
#Plots schools_closed start dates for each country 

nnl = np.argwhere(df.schools_closed.notnull() == True).transpose().tolist()[0]
strt = 0 #min is 0
end = 131 #max is 131
#ranges of countries can be chosen by uncommenting the ends of the next two lines
yp = df.iloc[nnl].sort_values(by='cc_index').reset_index()['cc_index'][strt:end]
xp = df.iloc[nnl].sort_values(by = 'cc_index').schools_closed[strt:end].values
df_yp = pd.DataFrame(yp.values,columns = ['yp'])
df_yp_c = df_yp.join(df_country_codes.set_index('A2 (ISO)'), on='yp')
fig = plt.figure(figsize=(8,len(yp)/6)) 
ax = fig.add_subplot(111)
ax.scatter(xp,yp)
for i, txt in enumerate(yp, start= strt):
    ax.annotate(txt, (xp[i-strt],yp[i]))
plt.yticks(ticks = [i for i in range(len(yp))], labels = df_yp_c.COUNTRY.values)
x_ticks = np.arange(np.datetime64('2020-01-21'), np.datetime64('2020-03-27'), np.timedelta64(2))
plt.xticks(ticks = x_ticks, labels = x_ticks, rotation=90)
plt.xlim(np.datetime64('2020-01-19'),np.datetime64('2020-03-27'))
plt.ylim(-1,len(yp))
plt.grid(True, alpha=0.2, color='red')
plt.title('Schools Closed')
#plt.savefig('schools_closed.jpg', bbox_inches='tight')
plt.show()

# %%
#Plots traveller_quarantine start dates for each country

nnl = np.argwhere(df.traveller_quarantine.notnull() == True).transpose().tolist()[0]
yp = df.iloc[nnl].sort_values(by='cc_index').reset_index()['cc_index'] 
xp = df.iloc[nnl].sort_values(by = 'cc_index').traveller_quarantine.values
df_yp = pd.DataFrame(yp.values,columns = ['yp'])
df_yp_c = df_yp.join(df_country_codes.set_index('A2 (ISO)'), on='yp')
fig = plt.figure(figsize=(8,len(yp)/5)) 
ax = fig.add_subplot(111)
ax.scatter(xp,yp)
for i, txt in enumerate(yp):
    ax.annotate(txt, (xp[i],yp[i]))
plt.yticks(ticks = [i for i in range(len(yp))], labels = df_yp_c.COUNTRY.values)
x_ticks = np.arange(np.datetime64('2020-01-21'), np.datetime64('2020-03-27'), np.timedelta64(2))
plt.xticks(ticks = x_ticks, labels = x_ticks, rotation=90)
plt.xlim(np.datetime64('2020-01-19'),np.datetime64('2020-03-27'))
plt.ylim(-1,len(yp))
plt.grid(True, alpha=0.2, color='red')
plt.title('Traveller Quarantine')
#plt.savefig('traveller_quarantine.jpg', bbox_inches='tight')
plt.show()

# %%
#Plots border_control start dates for each country

nnl = np.argwhere(df.border_control.notnull() == True).transpose().tolist()[0]
yp = df.iloc[nnl].sort_values(by='cc_index').reset_index()['cc_index'] 
xp = df.iloc[nnl].sort_values(by = 'cc_index').border_control.values
df_yp = pd.DataFrame(yp.values,columns = ['yp'])
df_yp_c = df_yp.join(df_country_codes.set_index('A2 (ISO)'), on='yp')
fig = plt.figure(figsize=(8,len(yp)/5)) 
ax = fig.add_subplot(111)
ax.scatter(xp,yp)
for i, txt in enumerate(yp):
    ax.annotate(txt, (xp[i],yp[i]))
plt.yticks(ticks = [i for i in range(len(yp))], labels = df_yp_c.COUNTRY.values)
x_ticks = np.arange(np.datetime64('2020-01-21'), np.datetime64('2020-03-27'), np.timedelta64(2))
plt.xticks(ticks = x_ticks, labels = x_ticks, rotation=90)
plt.xlim(np.datetime64('2020-01-19'),np.datetime64('2020-03-27'))
plt.ylim(-1,len(yp))
plt.grid(True, alpha=0.2, color='red')
plt.title('Border Control')
#plt.savefig('border_control.jpg', bbox_inches='tight')
plt.show()

# %%
#Plots closure_leisureandbars start dates for each country

nnl = np.argwhere(df.closure_leisureandbars.notnull() == True).transpose().tolist()[0]
yp = df.iloc[nnl].sort_values(by='cc_index').reset_index()['cc_index'] 
xp = df.iloc[nnl].sort_values(by = 'cc_index').closure_leisureandbars.values
df_yp = pd.DataFrame(yp.values,columns = ['yp'])
df_yp_c = df_yp.join(df_country_codes.set_index('A2 (ISO)'), on='yp')
fig = plt.figure(figsize=(8,len(yp)/5)) 
ax = fig.add_subplot(111)
ax.scatter(xp,yp)
for i, txt in enumerate(yp):
    ax.annotate(txt, (xp[i],yp[i]))
plt.yticks(ticks = [i for i in range(len(yp))], labels = df_yp_c.COUNTRY.values)
x_ticks = np.arange(np.datetime64('2020-01-21'), np.datetime64('2020-03-27'), np.timedelta64(2))
plt.xticks(ticks = x_ticks, labels = x_ticks, rotation=90)
plt.xlim(np.datetime64('2020-01-19'),np.datetime64('2020-03-27'))
plt.ylim(-1,len(yp))
plt.grid(True, alpha=0.2, color='red')
plt.title('Closure Leisure and Bars')
#plt.savefig('closure_leisureandbars.jpg', bbox_inches='tight')
plt.show()

# %%
#Plots lockdown start dates for each country

nnl = np.argwhere(df.lockdown.notnull() == True).transpose().tolist()[0] 
yp = df.iloc[nnl].sort_values(by='cc_index').reset_index()['cc_index'] 
xp = df.iloc[nnl].sort_values(by = 'cc_index').lockdown.values
df_yp = pd.DataFrame(yp.values,columns = ['yp'])
df_yp_c = df_yp.join(df_country_codes.set_index('A2 (ISO)'), on='yp')
fig = plt.figure(figsize=(8,len(yp)/5)) 
ax = fig.add_subplot(111)
ax.scatter(xp,yp)
for i, txt in enumerate(yp):
    ax.annotate(txt, (xp[i],yp[i]))
plt.yticks(ticks = [i for i in range(len(yp))], labels = df_yp_c.COUNTRY.values)
x_ticks = np.arange(np.datetime64('2020-01-21'), np.datetime64('2020-03-27'), np.timedelta64(2))
plt.xticks(ticks = x_ticks, labels = x_ticks, rotation=90)
plt.xlim(np.datetime64('2020-01-19'),np.datetime64('2020-03-27'))
plt.ylim(-1,len(yp))
plt.grid(True, alpha=0.2, color='red')
plt.title('Lockdown')
#plt.savefig('lockdown.jpg', bbox_inches='tight')
plt.show()

# %%
#Plots home_office start dates for each country

nnl = np.argwhere(df.home_office.notnull() == True).transpose().tolist()[0]
yp = df.iloc[nnl].sort_values(by='cc_index').reset_index()['cc_index'] 
xp = df.iloc[nnl].sort_values(by = 'cc_index').home_office.values
df_yp = pd.DataFrame(yp.values,columns = ['yp'])
df_yp_c = df_yp.join(df_country_codes.set_index('A2 (ISO)'), on='yp')
fig = plt.figure(figsize=(8,len(yp)/5)) 
ax = fig.add_subplot(111)
ax.scatter(xp,yp)
for i, txt in enumerate(yp):
    ax.annotate(txt, (xp[i],yp[i]))
plt.yticks(ticks = [i for i in range(len(yp))], labels = df_yp_c.COUNTRY.values)
x_ticks = np.arange(np.datetime64('2020-01-21'), np.datetime64('2020-03-27'), np.timedelta64(2))
plt.xticks(ticks = x_ticks, labels = x_ticks, rotation=90)
plt.xlim(np.datetime64('2020-01-19'),np.datetime64('2020-03-27'))
plt.ylim(-1,len(yp))
plt.grid(True, alpha=0.2, color='red')
plt.title('Home Office')
#plt.savefig('home_office.jpg', bbox_inches='tight')
plt.show()

# %%
#Plots primary_residence start dates for each country

nnl = np.argwhere(df.primary_residence.notnull() == True).transpose().tolist()[0]
yp = df.iloc[nnl].sort_values(by='cc_index').reset_index()['cc_index'] 
xp = df.iloc[nnl].sort_values(by = 'cc_index').primary_residence.values
df_yp = pd.DataFrame(yp.values,columns = ['yp'])
df_yp_c = df_yp.join(df_country_codes.set_index('A2 (ISO)'), on='yp')
fig = plt.figure(figsize=(8,len(yp)/5)) 
ax = fig.add_subplot(111)
ax.scatter(xp,yp)
for i, txt in enumerate(yp):
    ax.annotate(txt, (xp[i],yp[i]))
plt.yticks(ticks = [i for i in range(len(yp))], labels = df_yp_c.COUNTRY.values)
x_ticks = np.arange(np.datetime64('2020-01-21'), np.datetime64('2020-03-27'), np.timedelta64(2))
plt.xticks(ticks = x_ticks, labels = x_ticks, rotation=90)
plt.xlim(np.datetime64('2020-01-19'),np.datetime64('2020-03-27'))
plt.ylim(-1,len(yp))
plt.grid(True, alpha=0.2, color='red')
plt.title('Primary Residence')
#plt.savefig('primary_residence.jpg', bbox_inches='tight')
plt.show()

# %%
#Plots test_limitations start dates for each country

nnl = np.argwhere(df.test_limitations.notnull() == True).transpose().tolist()[0]
yp = df.iloc[nnl].sort_values(by='cc_index').reset_index()['cc_index'] 
xp = df.iloc[nnl].sort_values(by = 'cc_index').test_limitations.values
df_yp = pd.DataFrame(yp.values,columns = ['yp'])
df_yp_c = df_yp.join(df_country_codes.set_index('A2 (ISO)'), on='yp')
fig = plt.figure(figsize=(8,len(yp)/5)) 
ax = fig.add_subplot(111)
ax.scatter(xp,yp)
for i, txt in enumerate(yp):
    ax.annotate(txt, (xp[i],yp[i]))
plt.yticks(ticks = [i for i in range(len(yp))], labels = df_yp_c.COUNTRY.values)
x_ticks = np.arange(np.datetime64('2020-01-21'), np.datetime64('2020-03-27'), np.timedelta64(2))
plt.xticks(ticks = x_ticks, labels = x_ticks, rotation=90)
plt.xlim(np.datetime64('2020-01-19'),np.datetime64('2020-03-27'))
plt.ylim(-1,len(yp))
plt.grid(True, alpha=0.2, color='red')
plt.title('Test Limitations')
#plt.savefig('test_limitations.jpg', bbox_inches='tight')
plt.show()
